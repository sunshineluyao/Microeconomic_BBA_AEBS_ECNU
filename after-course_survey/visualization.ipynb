# %%
import xlrd
import seaborn as sns
import folium
import numpy as np
import  webbrowser
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'After-course survey for microeconomics.xlsx'

# %%
def load_survey(path):
    survey = xlrd.open_workbook(path)
    table = survey.sheet_by_name('Sheet1')
    return table

# %%
table = load_survey(path)
col_values = table.col_values(9)
print(col_values)
title_name = col_values[0]
# Out:
# ['9、(English)', 'Intermediate', 'Advanced', 'Advanced', 'Intermediate', 'Advanced', 'Intermediate', 'Intermediate', 'Advanced', 'Advanced', 'Advanced', 'Advanced', 'Intermediate', 'Advanced', 'Advanced', 'Advanced', 'Advanced', 'Intermediate', 'Elementary', 'Advanced', 'Advanced', 'Advanced', 'Intermediate', 'Intermediate', 'Advanced', 'Elementary', 'Intermediate', 'Advanced', 'Intermediate', 'Advanced', 'Intermediate', 'Intermediate', 'Intermediate', 'Advanced', 'Advanced', 'Advanced', 'Advanced', 'Intermediate', 'Advanced', 'Intermediate', 'Intermediate', 'Advanced', 'Advanced', 'Advanced', 'Advanced', 'Advanced', 'Intermediate', 'Advanced', 'Intermediate']

# %%
def count_num(data):
    value_vs_number = {}
    for i in data:
        i = i.split(',')[0]
        if i in value_vs_number.keys():
            
            value_vs_number[i] += 1
        else:
            value_vs_number[i] = 1
    return value_vs_number

# %%
def load_data(path, colume):
    table = load_survey(path)
    col_values = table.col_values(colume)
    title = col_values[0].split("、")[-1]
    col_values = col_values[1:]
    return col_values, title
def draw_figure(data, order=None, palette = ['red','blue']):
    xx = list(data.values())
    index = np.argsort(xx)
    xx.sort(reverse=True)
    yy = [list(data.keys())[i] for i in index[::-1]]
    ax = sns.barplot(x=xx,y=yy, order=order, orient='h', palette=palette)
    ax.set_xlabel("Number of Students", fontsize=14)
    if order==None:
        patches = ax.patches
    else:
        patches = ax.patches[:len(order)]
    total = 0
    for i in patches:
        total += i.get_width()
    ax.set_xticks(list(range(0,int(ax.patches[0].get_width())+21,5)))
    for i in patches:
        ax.text(i.get_width(), i.get_y()+0.5, f'{str(int(i.get_width()))}({str(round((i.get_width()/total)*100, 2))}%)', fontsize=12, color='gray')
    return ax
def answer_to_txt(col_values):
    res = []
    for i in col_values:
        res.append(i.split('〖')[-1].split('〗')[0]+'\n')
    return res

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,1)
data = count_num(col_values)
draw_figure(data)
plt.title(title)
plt.savefig('./pictures/gender.png',bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,6)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/time_zone.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,8)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title('Mandarin')
plt.savefig('./pictures/Mandarin.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,9)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title('English')
plt.savefig('./pictures/English.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,11)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title('Calculus')
plt.savefig('./pictures/Calculus.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,12)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title('Linear Algebra')
plt.savefig('./pictures/Linear_Algebra.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,13)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title('Python')
plt.savefig('./pictures/python.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,14)
data = count_num(answer_to_txt(col_values))
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/work_field.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,15)
data = count_num(answer_to_txt(col_values))
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/after_education.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,16)
data = count_num(answer_to_txt(col_values))
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/industry_to_work.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,17)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/LinkedIn.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,29)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/learn_economics.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,30)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/read_economics_book.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,31)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/online_webinar.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,32)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/workshops.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,33)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/economics_related_course.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,34)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/define_economics.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,36)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/if_economics_useful.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,38)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/internships.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,39)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/start-up.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,40)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/academic_research.png',bbox_inches='tight')

# %%
table = load_survey(path)
col_values = table.col_values(41)
title = col_values[0].split("、")[-1]
print(f'problem:{title}')
col_values = col_values[1:]
xx = []
for i in col_values:
    i = i.split('┋')
    if isinstance(i, list):
        for ii in i:
            xx.append(ii)
    else:
        xx.append(i)
data = count_num(xx)
xx = list(data.values())
index = np.argsort(xx)
xx.sort(reverse=True)
yy = [list(data.keys())[i] for i in index[::-1]]
ax = sns.barplot(x=xx,y=yy, orient='h')
ax.set_title(title)
ax.set_xlabel("Number of Students", fontsize=14)
total = 0
for i in ax.patches[:4]:
    total += i.get_width()
ax.set_xticks(list(range(0,int(ax.patches[0].get_width())+21,5)))
for i in ax.patches:
    ax.text(i.get_width(), i.get_y()+0.5, f'{str(int(i.get_width()))}({str(round((i.get_width()/total)*100, 2))}%)', fontsize=12, color='gray')
    
plt.savefig('./pictures/teach.png',bbox_inches='tight')
# Out:
# problem:Which teaching style inspires and facilitates your learning more?

# %%
col_values, title = load_data(path,42)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/hours_to_study.png',bbox_inches='tight')

# %%
table = load_survey(path)
col_values = table.col_values(43)
title = col_values[0].split("、")[-1]
print(f'problem:{title}')
col_values = col_values[1:]
xx = []
for i in col_values:
    i = i.split('┋')
    if isinstance(i, list):
        for ii in i:
            xx.append(ii)
    else:
        xx.append(i)
data = count_num(xx)
xx = list(data.values())
index = np.argsort(xx)
xx.sort(reverse=True)
yy = [list(data.keys())[i] for i in index[::-1]]
ax = sns.barplot(x=xx,y=yy, orient='h')
ax.set_title(title)
ax.set_xlabel("Number of Students", fontsize=14)
total = 0
for i in ax.patches[:4]:
    total += i.get_width()
ax.set_xticks(list(range(0,int(ax.patches[0].get_width())+21,5)))
for i in ax.patches:
    ax.text(i.get_width(), i.get_y()+0.5, f'{str(int(i.get_width()))}({str(round((i.get_width()/total)*100, 2))}%)', fontsize=12, color='gray')

plt.savefig('./pictures/learning.png',bbox_inches='tight')
# Out:
# problem:Choose all that applies to your past learning experience.

# %%
col_values, title = load_data(path,44)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/speak_in_public.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,45)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/work_in_team.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,46)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/leader.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,47)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/team_role.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,48)
data = count_num(col_values)
draw_figure(data,palette=['red','blue'])
plt.title(title)
plt.savefig('./pictures/lead_team.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,50)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/presentation.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,51)
data = count_num(col_values)
draw_figure(data,palette=None)
plt.title(title)
plt.savefig('./pictures/participate_team.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,52)
data = count_num(col_values)
if len(data) <= 2:
    palette=['red','blue']
else:
    palette=None
draw_figure(data,palette=palette)
plt.title(title)
plt.savefig('./pictures/peer-evaluation.png',bbox_inches='tight')

# %%
col_values, title = load_data(path,53)
data = count_num(col_values)
if len(data) <= 2:
    palette=['red','blue']
else:
    palette=None
draw_figure(data,palette=palette)
plt.title(title)
plt.savefig('./pictures/choose_course.png',bbox_inches='tight')
# Out:
# E:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12310 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12310 missing from current font.
#   font.set_text(s, 0, flags=flags)
# E:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12311 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def count_num(data):
    value_vs_number = {}
    for i in data:
        if i in value_vs_number.keys():
            
            value_vs_number[i] += 1
        else:
            value_vs_number[i] = 1
    return value_vs_number
col_values, title = load_data(path,54)
data = count_num(col_values)
if len(data) <= 2:
    palette=['red','blue']
else:
    palette=None
draw_figure(data, order=['Practical experience in Economics','Ability, Network and Resources for future career','A systematic way \
of thinking','Theoretical knowledges in Economics','Collaboration in a diverse team'],palette=palette)
plt.title(title)
plt.savefig('./pictures/obtain.png',bbox_inches='tight')
